# %%
import hpSPMPlusStudio as hps
from hpSPMPlusStudio import NMICommand,NMIEndpoint,NMIDevice
import time
print(hps.help())
# Out:
# hpSPM+ API package:
# Version: 0.1.6
#
# Docs:
# C:\Users\furkan.eren\AppData\Local\Programs\Python\Python311\Lib\site-packages\hpSPMPlusStudio\Docs
# None

# %%
Endpoint = NMIEndpoint("192.168.10.53",9024)
Device = NMIDevice(Endpoint)

# %%
AdjustFiber = Device.ADJUSTFIBER()

# %%
print(AdjustFiber.Get_IsInit())
print(AdjustFiber.Set_Initialize())
print(AdjustFiber.Get_IsInit())

print(AdjustFiber.Get_Commands())
print(AdjustFiber.Get_NumSamples())
print(AdjustFiber.Get_NumAvg())
print(AdjustFiber.Get_Delay())
print(AdjustFiber.Get_MiddleDelay())
print(AdjustFiber.Get_KFiber())
print(AdjustFiber.Get_SlopeStepSize())
print(AdjustFiber.Get_SinPeriod())
print(AdjustFiber.Get_SlopeModeList())
print(AdjustFiber.Get_SlopeMode())
print(AdjustFiber.Get_Gamma())
print(AdjustFiber.Get_MaxPztVoltage())
print(AdjustFiber.Get_IsAutoKFiberEnable())

print(AdjustFiber.Get_Results())
print(AdjustFiber.Get_ResultMaxSlope())
print(AdjustFiber.Get_ResultMinSlope())
print(AdjustFiber.Get_ResultQuadraturePointPower())
print(AdjustFiber.Get_ResultFiberVoltage())
print(AdjustFiber.Get_ResultFiberPosition())
print(AdjustFiber.Get_ResultLaserPower())
print(AdjustFiber.Get_ResultFinesse())
print(AdjustFiber.Get_ResultVisibility())

print(AdjustFiber.Set_NumSamples(256))
print(AdjustFiber.Set_NumAvg(6))
print(AdjustFiber.Set_SlopeStepSize(6))
print(AdjustFiber.Set_SlopeMode("MaxSlope"))
print(AdjustFiber.Set_Gamma(0.85))
print(AdjustFiber.Set_AutoKFiberEnable())
# Out:
# {'ResponseStatus': True, 'IsInit': False, 'message': 'Successful'}
# {'ResponseStatus': True, 'message': 'Successful'}
# {'ResponseStatus': True, 'IsInit': True, 'message': 'Successful'}
# ['None', 'Get_Commands', 'Get_IsRunning', 'Get_IsInit', 'Get_NumSamples', 'Get_NumAvg', 'Get_Delay', 'Get_MiddleDelay', 'Get_KFiber', 'Get_SlopeStepSize', 'Get_SinPeriod', 'Get_SlopeModeList', 'Get_SlopeMode', 'Get_Gamma', 'Get_MaxPztVoltage', 'Get_IsAutoKFiberEnable', 'Get_Results', 'Get_ResultMaxSlope', 'Get_ResultMinSlope', 'Get_ResultQuadraturePointPower', 'Get_ResultFiberVoltage', 'Get_ResultFiberPosition', 'Get_ResultLaserPower', 'Get_ResultFinesse', 'Get_ResultVisibility', 'Get_ForwardDataList', 'Get_ForwardSlopeDataList', 'Get_BackwardDataList', 'Get_BackwardSlopeDataList', 'Set_NumSamples', 'Set_NumAvg', 'Set_Delay', 'Set_MiddleDelay', 'Set_KFiber', 'Set_SlopeStepSize', 'Set_SlopeMode', 'Set_Gamma', 'Set_AutoKFiberEnable', 'Set_AutoKFiberDisable', 'Set_Initialize', 'FindQuadrature', 'Stop']
# {'ResponseStatus': True, 'NumSamples': 512, 'message': 'Successful'}
# {'ResponseStatus': True, 'NumAvg': 1, 'message': 'Successful'}
# {'ResponseStatus': True, 'Delay': 1, 'Unit': 'μs', 'message': 'Successful'}
# {'ResponseStatus': True, 'MiddleDelay': 10, 'Unit': 'ms', 'message': 'Successful'}
# {'ResponseStatus': True, 'KFiber': 125, 'Unit': '(Å/V)', 'message': 'Successful'}
# {'ResponseStatus': True, 'SlopeStepSize': 10, 'message': 'Successful'}
# {'ResponseStatus': True, 'SinPeriod': 655, 'Unit': '(nm)', 'message': 'Successful'}
# {'ResponseStatus': True, 'SlopeModes': 'MaxSlope;MinSlope;AbsoluteMaxSlope', 'message': 'Successful'}
# {'ResponseStatus': True, 'SlopeMode': 'MaxSlope', 'message': 'Successful'}
# {'ResponseStatus': True, 'Gamma': 0.76, 'message': 'Successful'}
# {'ResponseStatus': True, 'MaxPztVoltage': 100, 'message': 'Successful'}
# {'ResponseStatus': True, 'IsAutoKFiberEnable': False, 'message': 'Successful'}
# {'ResponseStatus': True, 'MaxSlope': 0, 'MaxSlopeUnit': 'mV/Å', 'MinSlope': 0, 'MinSlopeUnit': 'µW', 'QuadraturePointPower': 0, 'QuadraturePointPowerUnit': 'µW', 'FiberVoltage': 0, 'FiberVoltageUnit': 'V', 'FiberPosition': 0, 'FiberPositionUnit': 'nm', 'LaserPower': 0, 'LaserPowerUnit': 'µW', 'Finesse': 0, 'Visibility': 0, 'message': 'Successful'}
# {'ResponseStatus': True, 'MaxSlope': 0, 'Unit': 'mV/Å', 'message': 'Successful'}
# {'ResponseStatus': True, 'MinSlope': 0, 'Unit': 'mV/Å', 'message': 'Successful'}
# {'ResponseStatus': True, 'QuadraturePointPower': 0, 'Unit': 'µW', 'message': 'Successful'}
# {'ResponseStatus': True, 'FiberVoltage': 0, 'Unit': 'V', 'message': 'Successful'}
# {'ResponseStatus': True, 'FiberPosition': 0, 'Unit': 'nm', 'message': 'Successful'}
# {'ResponseStatus': True, 'LaserPower': 0, 'Unit': 'µW', 'message': 'Successful'}
# {'ResponseStatus': True, 'Finesse': 0, 'message': 'Successful'}
# {'ResponseStatus': True, 'Visibility': 0, 'message': 'Successful'}
# {'ResponseStatus': True, 'message': 'Successful'}
# {'ResponseStatus': True, 'message': 'Successful'}
# {'ResponseStatus': True, 'message': 'Successful'}
# {'ResponseStatus': True, 'message': 'Successful'}
# {'ResponseStatus': True, 'message': 'Successful'}
# {'ResponseStatus': True, 'message': 'Successful'}

# %%
print(AdjustFiber.FindQuadrature())
time.sleep(5)
while(True):
    isTunning = (bool)(AdjustFiber.Get_IsRunning()["IsRunning"])
    if(isTunning==False):
        break
    time.sleep(0.5)
    print(isTunning)
# Out:
# {'ResponseStatus': True, 'message': 'Successful'}
# True
# True
# True
# True
# True
# True
# True

# %%
print(AdjustFiber.Set_AutoKFiberDisable())
print(AdjustFiber.Get_Results())
print(AdjustFiber.Get_ResultMaxSlope())
print(AdjustFiber.Get_ResultMinSlope())
print(AdjustFiber.Get_ResultQuadraturePointPower())
print(AdjustFiber.Get_ResultFiberVoltage())
print(AdjustFiber.Get_ResultFiberPosition())
print(AdjustFiber.Get_ResultLaserPower())
print(AdjustFiber.Get_ResultFinesse())
print(AdjustFiber.Get_ResultVisibility())
print(AdjustFiber.Stop())
# Out:
# {'ResponseStatus': True, 'message': 'Successful'}
# {'ResponseStatus': True, 'MaxSlope': 30.34637006966964, 'MaxSlopeUnit': 'mV/Å', 'MinSlope': 260.8343463419648, 'MinSlopeUnit': 'µW', 'QuadraturePointPower': 260.8343463419648, 'QuadraturePointPowerUnit': 'µW', 'FiberVoltage': 13.354899746696372, 'FiberVoltageUnit': 'V', 'FiberPosition': 414.681712962963, 'FiberPositionUnit': 'nm', 'LaserPower': 1322.6992678947372, 'LaserPowerUnit': 'µW', 'Finesse': 1.5879428741815285, 'Visibility': 0.715447121883665, 'message': 'Successful'}
# {'ResponseStatus': True, 'MaxSlope': 30.34637006966964, 'Unit': 'mV/Å', 'message': 'Successful'}
# {'ResponseStatus': True, 'MinSlope': 30.34637006966964, 'Unit': 'mV/Å', 'message': 'Successful'}
# {'ResponseStatus': True, 'QuadraturePointPower': 260.8343463419648, 'Unit': 'µW', 'message': 'Successful'}
# {'ResponseStatus': True, 'FiberVoltage': 13.354899746696372, 'Unit': 'V', 'message': 'Successful'}
# {'ResponseStatus': True, 'FiberPosition': 414.681712962963, 'Unit': 'nm', 'message': 'Successful'}
# {'ResponseStatus': True, 'LaserPower': 1322.6992678947372, 'Unit': 'µW', 'message': 'Successful'}
# {'ResponseStatus': True, 'Finesse': 1.5879428741815285, 'message': 'Successful'}
# {'ResponseStatus': True, 'Visibility': 0.715447121883665, 'message': 'Successful'}
# {'ResponseStatus': True, 'message': 'Successful'}

# %%
forwardData = AdjustFiber.Get_ForwardDataList()

# %%
backwardData = AdjustFiber.Get_BackwardDataList()

# %%
import matplotlib.pyplot as plt


# Forward ve backward veriler
keys = forwardData['Keys']
forward_values = forwardData['Values']
backward_values = backwardData['Values']

# Grafiği çizdirme
plt.figure(figsize=(10, 6))

# Forward çizgisi
plt.plot(keys, forward_values, label="Forward", color="blue", marker="o")

# Backward çizgisi
plt.plot(keys, backward_values, label="Backward (Reversed)", color="red", marker="x", linestyle="--")

# Grafik detayları
plt.title("Forward and Backward Visualization")
plt.xlabel("Keys")
plt.ylabel("Values")
plt.grid(True)
plt.legend()
plt.show()
