# %%
from pond_agent import setup_logging

# For development - more verbose console output
setup_logging(console_level="INFO", file_level="DEBUG")
# Out:
# 2024-12-26 00:10:02.745 - root - INFO - ================================================================================
# 2024-12-26 00:10:02.746 - root - INFO - Logging initialized: console=INFO, file=DEBUG
# 2024-12-26 00:10:02.747 - root - INFO - Log file: /home/ubuntu/pond-agent/examples/sybil_address/logs/20241226.log
# 2024-12-26 00:10:02.748 - root - INFO - ================================================================================

# %%
from pond_agent import CompetitionAgent

# Initialize the agent
agent = CompetitionAgent(
    working_dir=".",
    competition_url="https://cryptopond.xyz/modelFactory/detail/2",
    llm_provider="openai",
    model_name="gpt-4o"
)
# Out:
# 2024-12-26 00:10:02.757 - pond_agent.llm - INFO - Initializing LLMClient with provider=openai, model=gpt-4o
# 2024-12-26 00:10:02.761 - pond_agent.llm - INFO - Successfully loaded .env file
# 2024-12-26 00:10:02.794 - pond_agent.llm - INFO - Successfully initialized OpenAI client
# 2024-12-26 00:10:02.796 - pond_agent.competition.utils - INFO - Reading Excel data dictionary from /home/ubuntu/pond-agent/examples/sybil_address/input/data_dictionary.xlsx
# 2024-12-26 00:10:02.972 - pond_agent.llm - INFO - Getting response using openai
# 2024-12-26 00:10:02.973 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2024-12-26 00:10:10.044 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-26 00:10:10.053 - pond_agent.llm - INFO - Successfully parsed OpenAI response as JSON

# %%
# Run the complete auto model development pipeline
agent.run()
# Out:
# 2024-12-26 00:10:10.060 - pond_agent.competition.agent - INFO - Starting model development pipeline
# 2024-12-26 00:10:10.062 - pond_agent.competition.agent - INFO - Processing data
# 2024-12-26 00:10:10.062 - pond_agent.competition.data_processor - INFO - Processing raw data files
# 2024-12-26 00:10:10.064 - pond_agent.competition.data_processor - INFO - Generating data processing script
# 2024-12-26 00:10:12.224 - pond_agent.competition.utils - INFO - Loaded 5 datasets from /home/ubuntu/pond-agent/examples/sybil_address/input/dataset
# 2024-12-26 00:10:12.225 - pond_agent.competition.utils - INFO -   - TOKEN_TRANSFERS: shape=(661444, 17)
# 2024-12-26 00:10:12.226 - pond_agent.competition.utils - INFO -   - TEST_ADDRESSES: shape=(4822, 1)
# 2024-12-26 00:10:12.227 - pond_agent.competition.utils - INFO -   - DEX_SWAPS: shape=(128634, 28)
# 2024-12-26 00:10:12.228 - pond_agent.competition.utils - INFO -   - TRAIN_ADDRESSES: shape=(27320, 2)
# 2024-12-26 00:10:12.228 - pond_agent.competition.utils - INFO -   - TRANSACTIONS: shape=(1048286, 27)
# 2024-12-26 00:10:12.230 - pond_agent.llm - INFO - Getting response using openai
# 2024-12-26 00:10:12.231 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2024-12-26 00:10:30.607 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-26 00:10:30.610 - pond_agent.competition.data_processor - INFO - Saved processing script to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/scripts/preprocess_data.py
# 2024-12-26 00:10:31.118 - pond_agent.competition.data_processor - INFO - Loading datasets...
# 2024-12-26 00:10:42.816 - pond_agent.competition.data_processor - INFO - Processing TRAIN_ADDRESSES...
# 2024-12-26 00:10:42.817 - pond_agent.competition.data_processor - INFO - Processing TRANSACTIONS...
# 2024-12-26 00:10:43.203 - pond_agent.competition.data_processor - INFO - Processing TOKEN_TRANSFERS...
# 2024-12-26 00:10:43.403 - pond_agent.competition.data_processor - INFO - Processing DEX_SWAPS...
# 2024-12-26 00:10:43.431 - pond_agent.competition.data_processor - INFO - Saving processed data...
# 2024-12-26 00:10:43.608 - pond_agent.competition.data_processor - INFO - Data preprocessing completed.
# 2024-12-26 00:10:44.240 - pond_agent.competition.data_processor - INFO - Successfully executed data processing script
# 2024-12-26 00:10:44.262 - pond_agent.competition.utils - INFO - Loaded 4 datasets from /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/processed_data
# 2024-12-26 00:10:44.263 - pond_agent.competition.utils - INFO -   - TRAIN_ADDRESSES: shape=(27320, 2)
# 2024-12-26 00:10:44.263 - pond_agent.competition.utils - INFO -   - DEX_SWAPS: shape=(5614, 4)
# 2024-12-26 00:10:44.264 - pond_agent.competition.utils - INFO -   - TRANSACTIONS: shape=(87953, 4)
# 2024-12-26 00:10:44.265 - pond_agent.competition.utils - INFO -   - TOKEN_TRANSFERS: shape=(62594, 4)
# 2024-12-26 00:10:44.266 - pond_agent.competition.agent - INFO - Engineering features
# 2024-12-26 00:10:44.266 - pond_agent.competition.feature_engineer - INFO - Engineering features
# 2024-12-26 00:10:44.267 - pond_agent.competition.feature_engineer - INFO - Generating feature engineering script
# 2024-12-26 00:10:44.287 - pond_agent.competition.utils - INFO - Loaded 4 datasets from /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/processed_data
# 2024-12-26 00:10:44.287 - pond_agent.competition.utils - INFO -   - TRAIN_ADDRESSES: shape=(27320, 2)
# 2024-12-26 00:10:44.288 - pond_agent.competition.utils - INFO -   - DEX_SWAPS: shape=(5614, 4)
# 2024-12-26 00:10:44.289 - pond_agent.competition.utils - INFO -   - TRANSACTIONS: shape=(87953, 4)
# 2024-12-26 00:10:44.290 - pond_agent.competition.utils - INFO -   - TOKEN_TRANSFERS: shape=(62594, 4)
# 2024-12-26 00:10:44.291 - pond_agent.llm - INFO - Getting response using openai
# 2024-12-26 00:10:44.292 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2024-12-26 00:10:53.825 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-26 00:10:53.828 - pond_agent.competition.feature_engineer - INFO - Saved feature engineering script to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/scripts/engineer_features.py
# 2024-12-26 00:10:54.727 - pond_agent.competition.feature_engineer - INFO - Loading datasets...
# 2024-12-26 00:10:54.858 - pond_agent.competition.feature_engineer - INFO - Calculating features...
# 2024-12-26 00:10:54.996 - pond_agent.competition.feature_engineer - INFO - Merging features with training labels...
# 2024-12-26 00:10:55.084 - pond_agent.competition.feature_engineer - INFO - Normalizing features...
# 2024-12-26 00:10:55.092 - pond_agent.competition.feature_engineer - INFO - Saving feature table...
# 2024-12-26 00:10:55.180 - pond_agent.competition.feature_engineer - INFO - Feature engineering completed and saved to: /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/feature_data/train.parquet
# 2024-12-26 00:10:55.394 - pond_agent.competition.feature_engineer - INFO - Successfully executed feature engineering script
# 2024-12-26 00:10:55.400 - pond_agent.competition.utils - INFO - Loaded 1 datasets from /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/feature_data
# 2024-12-26 00:10:55.401 - pond_agent.competition.utils - INFO -   - TRAIN: shape=(27320, 11)
# 2024-12-26 00:10:55.402 - pond_agent.competition.agent - INFO - Building model
# 2024-12-26 00:10:55.403 - pond_agent.competition.model_builder - INFO - Training model
# 2024-12-26 00:10:55.403 - pond_agent.competition.model_builder - INFO - Generating model building script
# 2024-12-26 00:10:55.409 - pond_agent.competition.utils - INFO - Loaded 1 datasets from /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/feature_data
# 2024-12-26 00:10:55.410 - pond_agent.competition.utils - INFO -   - TRAIN: shape=(27320, 11)
# 2024-12-26 00:10:55.411 - pond_agent.llm - INFO - Getting response using openai
# 2024-12-26 00:10:55.412 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2024-12-26 00:11:02.340 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-26 00:11:02.344 - pond_agent.competition.model_builder - INFO - Saved model building script to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/scripts/build_model.py
# 2024-12-26 00:11:03.532 - pond_agent.competition.model_builder - INFO - Loading training data from: /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/feature_data/train.parquet
# 2024-12-26 00:11:03.591 - pond_agent.competition.model_builder - INFO - Splitting data into training and validation sets...
# 2024-12-26 00:11:03.598 - pond_agent.competition.model_builder - INFO - Initializing the Random Forest Classifier...
# 2024-12-26 00:11:03.599 - pond_agent.competition.model_builder - INFO - Training the model...
# 2024-12-26 00:11:03.841 - pond_agent.competition.model_builder - ERROR - Error executing model building script: Traceback (most recent call last):
#   File "/home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/scripts/build_model.py", line 37, in <module>
#     rf_model.fit(X_train, y_train)
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 419, in fit
#     y, expanded_class_weight = self._validate_y_class_weight(y)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 831, in _validate_y_class_weight
#     check_classification_targets(y)
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/utils/multiclass.py", line 222, in check_classification_targets
#     raise ValueError(
# ValueError: Unknown label type: unknown. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
#
# 2024-12-26 00:11:03.841 - pond_agent.competition.model_builder - INFO - Attempting to fix bug, 3 attempts remaining
# 2024-12-26 00:11:03.843 - pond_agent.llm - INFO - Getting response using openai
# 2024-12-26 00:11:03.844 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2024-12-26 00:11:10.404 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-26 00:11:11.401 - pond_agent.competition.model_builder - INFO - Loading training data from: /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/feature_data/train.parquet
# 2024-12-26 00:11:11.459 - pond_agent.competition.model_builder - INFO - Splitting data into training and validation sets...
# 2024-12-26 00:11:11.465 - pond_agent.competition.model_builder - INFO - Initializing the Random Forest Classifier...
# 2024-12-26 00:11:11.466 - pond_agent.competition.model_builder - INFO - Training the model...
# 2024-12-26 00:11:11.692 - pond_agent.competition.model_builder - ERROR - Error executing model building script: Traceback (most recent call last):
#   File "/home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/scripts/build_model.py", line 37, in <module>
#     rf_model.fit(X_train, y_train)
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 419, in fit
#     y, expanded_class_weight = self._validate_y_class_weight(y)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 831, in _validate_y_class_weight
#     check_classification_targets(y)
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/utils/multiclass.py", line 222, in check_classification_targets
#     raise ValueError(
# ValueError: Unknown label type: unknown. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
#
# 2024-12-26 00:11:11.694 - pond_agent.competition.model_builder - INFO - Attempting to fix bug, 2 attempts remaining
# 2024-12-26 00:11:11.696 - pond_agent.llm - INFO - Getting response using openai
# 2024-12-26 00:11:11.698 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2024-12-26 00:11:17.601 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-26 00:11:18.654 - pond_agent.competition.model_builder - INFO - Loading training data from: /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/feature_data/train.parquet
# 2024-12-26 00:11:18.708 - pond_agent.competition.model_builder - INFO - Splitting data into training and validation sets...
# 2024-12-26 00:11:18.714 - pond_agent.competition.model_builder - INFO - Initializing the Random Forest Classifier...
# 2024-12-26 00:11:18.715 - pond_agent.competition.model_builder - INFO - Training the model...
# 2024-12-26 00:11:20.971 - pond_agent.competition.model_builder - INFO - Validating the model...
# 2024-12-26 00:11:21.028 - pond_agent.competition.model_builder - INFO - Classification Report:
# 2024-12-26 00:11:21.029 - pond_agent.competition.model_builder - INFO -                precision    recall  f1-score   support
# 2024-12-26 00:11:21.030 - pond_agent.competition.model_builder - INFO -
# 2024-12-26 00:11:21.033 - pond_agent.competition.model_builder - INFO -            0       0.90      0.89      0.90      3361
# 2024-12-26 00:11:21.035 - pond_agent.competition.model_builder - INFO -            1       0.82      0.85      0.84      2103
# 2024-12-26 00:11:21.037 - pond_agent.competition.model_builder - INFO -
# 2024-12-26 00:11:21.039 - pond_agent.competition.model_builder - INFO -     accuracy                           0.87      5464
# 2024-12-26 00:11:21.041 - pond_agent.competition.model_builder - INFO -    macro avg       0.86      0.87      0.87      5464
# 2024-12-26 00:11:21.043 - pond_agent.competition.model_builder - INFO - weighted avg       0.87      0.87      0.87      5464
# 2024-12-26 00:11:21.045 - pond_agent.competition.model_builder - INFO -
# 2024-12-26 00:11:21.047 - pond_agent.competition.model_builder - INFO - Saving the model to: /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/models/random_forest_model.joblib
# 2024-12-26 00:11:21.076 - pond_agent.competition.model_builder - INFO - Model training and saving completed.
# 2024-12-26 00:11:21.288 - pond_agent.competition.model_builder - INFO - Successfully executed model building script
# 2024-12-26 00:11:21.289 - pond_agent.competition.agent - INFO - Generating submission
# 2024-12-26 00:11:21.290 - pond_agent.competition.submission_generator - INFO - Generating submission
# 2024-12-26 00:11:21.290 - pond_agent.competition.submission_generator - INFO - Generating submission script
# 2024-12-26 00:11:22.862 - pond_agent.competition.utils - INFO - Loaded 5 datasets from /home/ubuntu/pond-agent/examples/sybil_address/input/dataset
# 2024-12-26 00:11:22.863 - pond_agent.competition.utils - INFO -   - TOKEN_TRANSFERS: shape=(661444, 17)
# 2024-12-26 00:11:22.864 - pond_agent.competition.utils - INFO -   - TEST_ADDRESSES: shape=(4822, 1)
# 2024-12-26 00:11:22.865 - pond_agent.competition.utils - INFO -   - DEX_SWAPS: shape=(128634, 28)
# 2024-12-26 00:11:22.865 - pond_agent.competition.utils - INFO -   - TRAIN_ADDRESSES: shape=(27320, 2)
# 2024-12-26 00:11:22.866 - pond_agent.competition.utils - INFO -   - TRANSACTIONS: shape=(1048286, 27)
# 2024-12-26 00:11:22.868 - pond_agent.llm - INFO - Getting response using openai
# 2024-12-26 00:11:22.868 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2024-12-26 00:11:35.132 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-26 00:11:35.146 - pond_agent.competition.submission_generator - INFO - Saved submission script to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/scripts/generate_submission.py
# 2024-12-26 00:11:36.197 - pond_agent.competition.submission_generator - INFO - Loading test dataset...
# 2024-12-26 00:11:47.976 - pond_agent.competition.submission_generator - INFO - Calculating features for test set...
# 2024-12-26 00:11:48.584 - pond_agent.competition.submission_generator - INFO - Merging features with test addresses...
# 2024-12-26 00:11:48.650 - pond_agent.competition.submission_generator - INFO - Normalizing features...
# 2024-12-26 00:11:48.655 - pond_agent.competition.submission_generator - INFO - Loading the trained model...
# 2024-12-26 00:11:48.683 - pond_agent.competition.submission_generator - INFO - Generating predictions...
# 2024-12-26 00:11:48.726 - pond_agent.competition.submission_generator - INFO - Ensuring all test addresses are included in the submission...
# 2024-12-26 00:11:48.731 - pond_agent.competition.submission_generator - INFO - Saving the submission file...
# 2024-12-26 00:11:48.742 - pond_agent.competition.submission_generator - INFO - Submission file saved to: /home/ubuntu/pond-agent/examples/sybil_address/output/run_20241226_001002/submission.csv
# 2024-12-26 00:11:49.466 - pond_agent.competition.submission_generator - INFO - Successfully executed submission generation script
# 2024-12-26 00:11:49.478 - pond_agent.competition.agent - INFO - Model development pipeline completed
