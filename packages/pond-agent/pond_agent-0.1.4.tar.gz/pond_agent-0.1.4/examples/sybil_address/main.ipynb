# %%
import nest_asyncio
from pond_agent import setup_logging

# Allow asyncio to work with Jupyter
nest_asyncio.apply()

# Log to both terminal and file output
setup_logging(console_level="INFO", file_level="DEBUG")
# Out:
# 2025-01-01 19:37:32.789 - root - INFO - ================================================================================
# 2025-01-01 19:37:32.790 - root - INFO - Logging initialized: console=INFO, file=DEBUG
# 2025-01-01 19:37:32.791 - root - INFO - Log file: /home/ubuntu/pond-agent/examples/sybil_address/logs/20250101.log
# 2025-01-01 19:37:32.792 - root - INFO - ================================================================================

# %%
from pond_agent import CompetitionAgent

# Initialize the agent
agent = CompetitionAgent(
    working_dir=".",
    competition_url="https://cryptopond.xyz/modelFactory/detail/2",
    llm_provider="openai",
    model_name="gpt-4o"
)
# Out:
# 2025-01-01 19:37:32.802 - pond_agent.llm - INFO - Initializing LLMClient with provider=openai, model=gpt-4o
# 2025-01-01 19:37:32.804 - pond_agent.llm - INFO - Successfully loaded .env file
# 2025-01-01 19:37:32.834 - pond_agent.llm - INFO - Successfully initialized OpenAI client
# 2025-01-01 19:37:32.835 - pond_agent.competition.agent - WARNING - Competition files already exist in working directory. Skipping competition data scraping.

# %%
# Run the complete auto model development pipeline
agent.run()
# Out:
# 2025-01-01 19:37:32.842 - pond_agent.competition.agent - INFO - Starting model development pipeline
# 2025-01-01 19:37:32.843 - pond_agent.competition.utils - INFO - Reading Excel data dictionary from /home/ubuntu/pond-agent/examples/sybil_address/data_dictionary.xlsx
# 2025-01-01 19:37:33.125 - pond_agent.llm - INFO - Getting response using openai
# 2025-01-01 19:37:33.126 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2025-01-01 19:37:41.732 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-01 19:37:41.745 - pond_agent.llm - INFO - Successfully parsed OpenAI response as JSON
# 2025-01-01 19:37:41.746 - pond_agent.competition.agent - INFO - Processing data
# 2025-01-01 19:37:41.747 - pond_agent.competition.data_processor - INFO - Processing raw data files
# 2025-01-01 19:37:41.747 - pond_agent.competition.data_processor - INFO - Generating data processing script
# 2025-01-01 19:37:43.657 - pond_agent.competition.utils - INFO - Loaded 5 datasets from /home/ubuntu/pond-agent/examples/sybil_address/dataset
# 2025-01-01 19:37:43.658 - pond_agent.competition.utils - INFO -   - TOKEN_TRANSFERS: shape=(661444, 17)
# 2025-01-01 19:37:43.659 - pond_agent.competition.utils - INFO -   - TEST_ADDRESSES: shape=(4822, 1)
# 2025-01-01 19:37:43.659 - pond_agent.competition.utils - INFO -   - DEX_SWAPS: shape=(128634, 28)
# 2025-01-01 19:37:43.660 - pond_agent.competition.utils - INFO -   - TRAIN_ADDRESSES: shape=(27320, 2)
# 2025-01-01 19:37:43.661 - pond_agent.competition.utils - INFO -   - TRANSACTIONS: shape=(1048286, 27)
# 2025-01-01 19:37:43.663 - pond_agent.llm - INFO - Getting response using openai
# 2025-01-01 19:37:43.664 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2025-01-01 19:37:54.682 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-01 19:37:54.684 - pond_agent.competition.data_processor - INFO - Saved processing script to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/scripts/preprocess_data.py
# 2025-01-01 19:37:55.172 - pond_agent.competition.data_processor - INFO - Loading datasets...
# 2025-01-01 19:38:06.757 - pond_agent.competition.data_processor - INFO - Preprocessing TRAIN_ADDRESSES...
# 2025-01-01 19:38:06.765 - pond_agent.competition.data_processor - INFO - Preprocessing TRANSACTIONS...
# 2025-01-01 19:38:07.001 - pond_agent.competition.data_processor - INFO - Preprocessing TOKEN_TRANSFERS...
# 2025-01-01 19:38:07.120 - pond_agent.competition.data_processor - INFO - Preprocessing DEX_SWAPS...
# 2025-01-01 19:38:07.149 - pond_agent.competition.data_processor - INFO - Saving processed data...
# 2025-01-01 19:38:32.025 - pond_agent.competition.data_processor - INFO - Preprocessing complete.
# 2025-01-01 19:38:32.645 - pond_agent.competition.data_processor - INFO - Successfully executed data processing script
# 2025-01-01 19:38:34.091 - pond_agent.competition.utils - INFO - Loaded 4 datasets from /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/processed_data
# 2025-01-01 19:38:34.092 - pond_agent.competition.utils - INFO -   - TOKEN_TRANSFERS: shape=(661444, 17)
# 2025-01-01 19:38:34.093 - pond_agent.competition.utils - INFO -   - DEX_SWAPS: shape=(128634, 28)
# 2025-01-01 19:38:34.093 - pond_agent.competition.utils - INFO -   - TRAIN_ADDRESSES: shape=(27320, 2)
# 2025-01-01 19:38:34.094 - pond_agent.competition.utils - INFO -   - TRANSACTIONS: shape=(1048286, 27)
# 2025-01-01 19:38:34.121 - pond_agent.competition.agent - INFO - Engineering features
# 2025-01-01 19:38:34.122 - pond_agent.competition.feature_engineer - INFO - Engineering features
# 2025-01-01 19:38:34.123 - pond_agent.competition.feature_engineer - INFO - Generating feature engineering script
# 2025-01-01 19:38:35.487 - pond_agent.competition.utils - INFO - Loaded 4 datasets from /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/processed_data
# 2025-01-01 19:38:35.488 - pond_agent.competition.utils - INFO -   - TOKEN_TRANSFERS: shape=(661444, 17)
# 2025-01-01 19:38:35.490 - pond_agent.competition.utils - INFO -   - DEX_SWAPS: shape=(128634, 28)
# 2025-01-01 19:38:35.491 - pond_agent.competition.utils - INFO -   - TRAIN_ADDRESSES: shape=(27320, 2)
# 2025-01-01 19:38:35.491 - pond_agent.competition.utils - INFO -   - TRANSACTIONS: shape=(1048286, 27)
# 2025-01-01 19:38:35.493 - pond_agent.llm - INFO - Getting response using openai
# 2025-01-01 19:38:35.494 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2025-01-01 19:38:42.997 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-01 19:38:43.000 - pond_agent.competition.feature_engineer - INFO - Saved feature engineering script to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/scripts/engineer_features.py
# 2025-01-01 19:38:43.470 - pond_agent.competition.feature_engineer - INFO - Loading datasets...
# 2025-01-01 19:38:55.212 - pond_agent.competition.feature_engineer - INFO - Aggregating transaction data...
# 2025-01-01 19:38:56.503 - pond_agent.competition.feature_engineer - INFO - Aggregating token transfer data...
# 2025-01-01 19:38:56.901 - pond_agent.competition.feature_engineer - INFO - Aggregating DEX swap data...
# 2025-01-01 19:38:56.955 - pond_agent.competition.feature_engineer - INFO - Merging features...
# 2025-01-01 19:38:57.069 - pond_agent.competition.feature_engineer - INFO - Transforming numerical features...
# 2025-01-01 19:38:57.072 - pond_agent.competition.feature_engineer - INFO - Saving feature table to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/feature_data/train.parquet...
# 2025-01-01 19:38:57.740 - pond_agent.competition.feature_engineer - ERROR - Error executing feature engineering script: Traceback (most recent call last):
#   File "/home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/scripts/engineer_features.py", line 59, in <module>
#     features.to_parquet(output_path, index=False)
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/pandas/util/_decorators.py", line 333, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/pandas/core/frame.py", line 3113, in to_parquet
#     return to_parquet(
#            ^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/pandas/io/parquet.py", line 480, in to_parquet
#     impl.write(
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/pandas/io/parquet.py", line 190, in write
#     table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pyarrow/table.pxi", line 4751, in pyarrow.lib.Table.from_pandas
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/pyarrow/pandas_compat.py", line 638, in dataframe_to_arrays
#     arrays[i] = maybe_fut.result()
#                 ^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/pyarrow/pandas_compat.py", line 612, in convert_column
#     raise e
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/pyarrow/pandas_compat.py", line 606, in convert_column
#     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pyarrow/array.pxi", line 360, in pyarrow.lib.array
#   File "pyarrow/array.pxi", line 87, in pyarrow.lib._ndarray_to_array
#   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# pyarrow.lib.ArrowTypeError: ("Expected bytes, got a 'int' object", 'Conversion failed for column FROM_ADDRESS_x with type object')
#
# 2025-01-01 19:38:57.741 - pond_agent.competition.feature_engineer - INFO - Attempting to fix bug, 3 attempts remaining
# 2025-01-01 19:38:57.743 - pond_agent.llm - INFO - Getting response using openai
# 2025-01-01 19:38:57.744 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2025-01-01 19:39:04.635 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-01 19:39:05.058 - pond_agent.competition.feature_engineer - INFO - Loading datasets...
# 2025-01-01 19:39:16.283 - pond_agent.competition.feature_engineer - INFO - Aggregating transaction data...
# 2025-01-01 19:39:17.208 - pond_agent.competition.feature_engineer - INFO - Aggregating token transfer data...
# 2025-01-01 19:39:17.597 - pond_agent.competition.feature_engineer - INFO - Aggregating DEX swap data...
# 2025-01-01 19:39:17.652 - pond_agent.competition.feature_engineer - INFO - Merging features...
# 2025-01-01 19:39:17.762 - pond_agent.competition.feature_engineer - INFO - Transforming numerical features...
# 2025-01-01 19:39:17.765 - pond_agent.competition.feature_engineer - INFO - Saving feature table to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/feature_data/train.parquet...
# 2025-01-01 19:39:17.846 - pond_agent.competition.feature_engineer - INFO - Feature engineering completed successfully.
# 2025-01-01 19:39:18.474 - pond_agent.competition.feature_engineer - INFO - Successfully executed feature engineering script
# 2025-01-01 19:39:18.480 - pond_agent.competition.utils - INFO - Loaded 1 datasets from /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/feature_data
# 2025-01-01 19:39:18.481 - pond_agent.competition.utils - INFO -   - TRAIN: shape=(27320, 12)
# 2025-01-01 19:39:18.482 - pond_agent.competition.agent - INFO - Building model
# 2025-01-01 19:39:18.483 - pond_agent.competition.model_builder - INFO - Training model
# 2025-01-01 19:39:18.484 - pond_agent.competition.model_builder - INFO - Generating model building script
# 2025-01-01 19:39:18.490 - pond_agent.competition.utils - INFO - Loaded 1 datasets from /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/feature_data
# 2025-01-01 19:39:18.491 - pond_agent.competition.utils - INFO -   - TRAIN: shape=(27320, 12)
# 2025-01-01 19:39:18.493 - pond_agent.llm - INFO - Getting response using openai
# 2025-01-01 19:39:18.495 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2025-01-01 19:39:24.826 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-01 19:39:24.835 - pond_agent.competition.model_builder - INFO - Saved model building script to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/scripts/build_model.py
# 2025-01-01 19:39:25.847 - pond_agent.competition.model_builder - INFO - Loading training data...
# 2025-01-01 19:39:25.895 - pond_agent.competition.model_builder - INFO - Splitting data into training and validation sets...
# 2025-01-01 19:39:25.903 - pond_agent.competition.model_builder - INFO - Initializing the Random Forest Classifier...
# 2025-01-01 19:39:25.904 - pond_agent.competition.model_builder - INFO - Training the model...
# 2025-01-01 19:39:26.126 - pond_agent.competition.model_builder - ERROR - Error executing model building script: Traceback (most recent call last):
#   File "/home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/scripts/build_model.py", line 41, in <module>
#     rf_model.fit(X_train, y_train)
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 419, in fit
#     y, expanded_class_weight = self._validate_y_class_weight(y)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 831, in _validate_y_class_weight
#     check_classification_targets(y)
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/utils/multiclass.py", line 222, in check_classification_targets
#     raise ValueError(
# ValueError: Unknown label type: unknown. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
#
# 2025-01-01 19:39:26.127 - pond_agent.competition.model_builder - INFO - Attempting to fix bug, 3 attempts remaining
# 2025-01-01 19:39:26.128 - pond_agent.llm - INFO - Getting response using openai
# 2025-01-01 19:39:26.129 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2025-01-01 19:39:32.060 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-01 19:39:33.056 - pond_agent.competition.model_builder - INFO - Loading training data...
# 2025-01-01 19:39:33.112 - pond_agent.competition.model_builder - INFO - Splitting data into training and validation sets...
# 2025-01-01 19:39:33.118 - pond_agent.competition.model_builder - INFO - Initializing the Random Forest Classifier...
# 2025-01-01 19:39:33.119 - pond_agent.competition.model_builder - INFO - Training the model...
# 2025-01-01 19:39:33.343 - pond_agent.competition.model_builder - ERROR - Error executing model building script: Traceback (most recent call last):
#   File "/home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/scripts/build_model.py", line 41, in <module>
#     rf_model.fit(X_train, y_train)
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 419, in fit
#     y, expanded_class_weight = self._validate_y_class_weight(y)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/ensemble/_forest.py", line 831, in _validate_y_class_weight
#     check_classification_targets(y)
#   File "/home/ubuntu/miniforge3/envs/pond-agent/lib/python3.11/site-packages/sklearn/utils/multiclass.py", line 222, in check_classification_targets
#     raise ValueError(
# ValueError: Unknown label type: unknown. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
#
# 2025-01-01 19:39:33.344 - pond_agent.competition.model_builder - INFO - Attempting to fix bug, 2 attempts remaining
# 2025-01-01 19:39:33.345 - pond_agent.llm - INFO - Getting response using openai
# 2025-01-01 19:39:33.346 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2025-01-01 19:39:40.023 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-01 19:39:41.038 - pond_agent.competition.model_builder - INFO - Loading training data...
# 2025-01-01 19:39:41.091 - pond_agent.competition.model_builder - INFO - Splitting data into training and validation sets...
# 2025-01-01 19:39:41.098 - pond_agent.competition.model_builder - INFO - Initializing the Random Forest Classifier...
# 2025-01-01 19:39:41.099 - pond_agent.competition.model_builder - INFO - Training the model...
# 2025-01-01 19:39:43.439 - pond_agent.competition.model_builder - INFO - Validating the model...
# 2025-01-01 19:39:43.491 - pond_agent.competition.model_builder - INFO - Classification Report:
# 2025-01-01 19:39:43.501 - pond_agent.competition.model_builder - INFO -               precision    recall  f1-score   support
# 2025-01-01 19:39:43.502 - pond_agent.competition.model_builder - INFO -
# 2025-01-01 19:39:43.504 - pond_agent.competition.model_builder - INFO -            0       0.93      0.92      0.93      3361
# 2025-01-01 19:39:43.505 - pond_agent.competition.model_builder - INFO -            1       0.88      0.89      0.89      2103
# 2025-01-01 19:39:43.507 - pond_agent.competition.model_builder - INFO -
# 2025-01-01 19:39:43.509 - pond_agent.competition.model_builder - INFO -     accuracy                           0.91      5464
# 2025-01-01 19:39:43.510 - pond_agent.competition.model_builder - INFO -    macro avg       0.91      0.91      0.91      5464
# 2025-01-01 19:39:43.512 - pond_agent.competition.model_builder - INFO - weighted avg       0.91      0.91      0.91      5464
# 2025-01-01 19:39:43.512 - pond_agent.competition.model_builder - INFO -
# 2025-01-01 19:39:43.514 - pond_agent.competition.model_builder - INFO - Saving the model to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/models/random_forest_model.joblib...
# 2025-01-01 19:39:43.540 - pond_agent.competition.model_builder - INFO - Model training and saving completed.
# 2025-01-01 19:39:43.783 - pond_agent.competition.model_builder - INFO - Successfully executed model building script
# 2025-01-01 19:39:43.784 - pond_agent.competition.agent - INFO - Generating submission
# 2025-01-01 19:39:43.785 - pond_agent.competition.submission_generator - INFO - Generating submission
# 2025-01-01 19:39:43.785 - pond_agent.competition.submission_generator - INFO - Generating submission script
# 2025-01-01 19:39:45.204 - pond_agent.competition.utils - INFO - Loaded 5 datasets from /home/ubuntu/pond-agent/examples/sybil_address/dataset
# 2025-01-01 19:39:45.205 - pond_agent.competition.utils - INFO -   - TOKEN_TRANSFERS: shape=(661444, 17)
# 2025-01-01 19:39:45.205 - pond_agent.competition.utils - INFO -   - TEST_ADDRESSES: shape=(4822, 1)
# 2025-01-01 19:39:45.206 - pond_agent.competition.utils - INFO -   - DEX_SWAPS: shape=(128634, 28)
# 2025-01-01 19:39:45.207 - pond_agent.competition.utils - INFO -   - TRAIN_ADDRESSES: shape=(27320, 2)
# 2025-01-01 19:39:45.207 - pond_agent.competition.utils - INFO -   - TRANSACTIONS: shape=(1048286, 27)
# 2025-01-01 19:39:45.209 - pond_agent.llm - INFO - Getting response using openai
# 2025-01-01 19:39:45.210 - pond_agent.llm - INFO - Making OpenAI API call with model gpt-4o
# 2025-01-01 19:39:57.311 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-01 19:39:57.313 - pond_agent.competition.submission_generator - INFO - Saved submission script to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/scripts/generate_submission.py
# 2025-01-01 19:39:58.066 - pond_agent.competition.submission_generator - INFO - Loading test addresses...
# 2025-01-01 19:39:58.102 - pond_agent.competition.submission_generator - INFO - Loading datasets for feature engineering...
# 2025-01-01 19:40:10.327 - pond_agent.competition.submission_generator - INFO - Aggregating transaction data for test set...
# 2025-01-01 19:40:11.777 - pond_agent.competition.submission_generator - INFO - Aggregating token transfer data for test set...
# 2025-01-01 19:40:12.298 - pond_agent.competition.submission_generator - INFO - Aggregating DEX swap data for test set...
# 2025-01-01 19:40:12.353 - pond_agent.competition.submission_generator - INFO - Merging features for test set...
# 2025-01-01 19:40:12.419 - pond_agent.competition.submission_generator - INFO - Transforming numerical features for test set...
# 2025-01-01 19:40:12.422 - pond_agent.competition.submission_generator - INFO - Loading the trained model...
# 2025-01-01 19:40:13.246 - pond_agent.competition.submission_generator - INFO - Predicting labels for test set...
# 2025-01-01 19:40:13.298 - pond_agent.competition.submission_generator - INFO - Ensuring no missing predictions...
# 2025-01-01 19:40:13.300 - pond_agent.competition.submission_generator - INFO - Saving submission file to /home/ubuntu/pond-agent/examples/sybil_address/output/run_20250101_193732/submission.csv...
# 2025-01-01 19:40:13.311 - pond_agent.competition.submission_generator - INFO - Submission file created successfully.
# 2025-01-01 19:40:14.062 - pond_agent.competition.submission_generator - INFO - Successfully executed submission generation script
# 2025-01-01 19:40:14.074 - pond_agent.competition.agent - INFO - Model development pipeline completed
